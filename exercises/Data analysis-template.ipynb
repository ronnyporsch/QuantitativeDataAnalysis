# %%
import random as rd
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm
import math
import pylab
import scipy.stats as stats
import seaborn as sns
from scipy.stats import shapiro
from statsmodels.stats.outliers_influence import variance_inflation_factor
data = pd.read_excel("inputData/FB_data.xlsx", index_col=0)
df = data
df
# Out:
#         type  video  image                time  impressions  hashtags  emojis  \
# ID
# 1      Photo      0      1 2020-06-19 23:32:00       105655         0       0
# 2      Photo      0      1 2020-06-20 03:44:00        71400         0       0
# 3      Photo      0      1 2020-06-20 07:30:00        51903         1       0
# 4      Photo      0      1 2020-06-20 10:02:00        66841         0       0
# 5      Photo      0      1 2020-06-20 23:32:00        88444         0       0
# ...      ...    ...    ...                 ...          ...       ...     ...
# 1221   Photo      0      1 2021-05-29 08:01:00        39467         0       0
# 1222  Status      0      0 2021-05-29 23:03:00        72401         0       0
# 1223   Photo      0      1 2021-05-30 03:12:00        25594         0       0
# 1224   Photo      0      1 2021-05-30 08:00:00        18394         0       0
# 1225   Photo      0      1 2021-05-30 23:00:00        52382         0       0
#
#                                              text_clear  harrypotter  gaming  \
# ID
# 1     Der 20. Juni markiert den Beginn des Ringkrieg...            0       0
# 2     Neue Runde Falsche Zitate raten: Was haben Ric...            0       0
# 3     Zeit ein bisschen Verrücktheit in deinen Kleid...            0       0
# 4     Die Drittklässler in Hogwarts dürfen aus unter...            0       0
# 5     Wie sähe das Duell Darth Maul vs. Captain Amer...            0       0
# ...                                                 ...          ...     ...
# 1221  Geile Poster-Designs können wir uns den ganzen...            0       0
# 1222  Frage zum Sonntag: Welches Buch empfehlt ihr a...            0       0
# 1223  RAUM27 kommt aufs Elbenwald Festival! Das Duo ...            0       0
# 1224  Einmal wie Son Goku sein, nur ohne das ganze h...            0       0
# 1225  Sylvester Stallone arbeitet schon länger an ei...            0       0
#
#       ...  comments  other_clicks  image_view  link_clicks  video_play  \
# ID    ...
# 1     ...       118          4935         682            0           0
# 2     ...       334          3873         372            0           0
# 3     ...         8           378         144          139           0
# 4     ...        78          1271         271            0           0
# 5     ...        48          1782       11881           74           0
# ...   ...       ...           ...         ...          ...         ...
# 1221  ...         0            88         174           15           0
# 1222  ...       321          4150           0            0           0
# 1223  ...         0            82           4           21           0
# 1224  ...        11           100           6            0           0
# 1225  ...        17           592          75            0           0
#
#       text_sentiment  readability  chars  lottery  adv
# ID
# 1            0.00000           69    305        0    0
# 2            0.00000           72     89        0    0
# 3            0.00000           70    117        0    1
# 4           -0.43935           50    331        0    0
# 5            0.00000           71    327        0    0
# ...              ...          ...    ...      ...  ...
# 1221         0.00000           69    172        0    0
# 1222         0.00000           68     66        0    0
# 1223         0.24345           79    378        0    0
# 1224         0.33870           71    159        0    1
# 1225         0.00000           53    116        0    0
#
# [1181 rows x 35 columns]

# %%
# lock at dependend variable/s

# %%
# View the relationship between an independent and a dependent variable in the data points
plt.scatter(df['likes'], df['chars'])
plt.show()
# You can't really see a connection in this graphic yet

# %%
# Next, let's look at the distribution of our dependent variable.
sns.displot(df['likes'])
# The distribution is skewed to the right

# %%
# A transformation is recommended so that the distribution is closer to a normal distribution.
# we need to calculate for likes+1 (because if likes = 0 then it wont work)
likes_log = []
df['likes_ln'] = np.log(df['likes']+1)
sns.displot(df['likes_ln'])

# %%
# That already looks like a normal distribution

# %%
# Shapiro-Wilk-Test
shapiro(df['likes_ln'])
# p-value is greater than 0.05, so we can probably assume a normal distribution.
# The normal distribution of the dependent variable is not necessarily a prerequisite for a regression, 
# but it allows us to interpret the results better.
# Out:
# ShapiroResult(statistic=0.9976455827067109, pvalue=0.08635084199520093)

# %%
# Now let's check the connection between characters and likes (likes_ln) again
plt.scatter(df['likes_ln'], df['chars'])
plt.show()
# Now we can assume a connection. What connection do you see?

# %%
# --> we want to discover the relationshipt with regression analysis


#adding constant 

#OLS model

# %%
# Shapiro-Wilk-Test

# Normal distribution of the residuals is assumed

# %%
# QQ-Plot

# %%
# What happens if we add another variable?
# We could add the "control variable" product


#adding constant 

#OLS model


# We can see that this has a strong effect.
# Our R square has improved compared to the 1st model.

# %%
# Let's compare the R² values of the models

# Model 1


# Model 2


# List of all independent variables


# Create the comparison table


# Add the R² for each model

# %%
# Your task: find a better model for this data set explaining likes_ln! 
# Set up a table to compare several models with each other.

# %%
# are there any problems in the model? Calculate VIF
# We check whether there is multicollinearity. 
# This would mean that our results may be biased because several variables explain the same thing.

# results for the variables should be below 10, otherwise high correlation
# If a value is above 10, it correlates with another variable.

# %%
# We can use a correlation matrix to check which variables correlate strongly.

# %%
# My proposed model

# %%
# we see that there is an inverted u-shape effect between text length and engagement. Calculate optimum

# %%
# Likes for characters in the optimum

# %%
# Likes for actual characters 

# mean value chars data set

# %%
# Relative increase in likes

#p

# %%
# Visualize the relationship

# %%
# t-test


# mean value comparison


# t-Test


# Output
